# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree, DecisionTreeRegressor
import numpy as np
import os

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ## Decision Trees - Classification (CART)

# %%
iris = load_iris()
X = iris.data[:, 2:] # petal length and width
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
plot_tree(tree_clf,
        feature_names=iris.feature_names,  
        class_names=iris.target_names,
        filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'sepal length (cm) <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(0.6, 0.5, 'sepal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica')]

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# ## Decision Trees - Regression (CART)

# %%
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 4 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 10

# %%
tree_reg = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg.fit(X, y)
plot_tree(tree_reg,
        filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 0.197\nsquared_error = 0.098\nsamples = 200\nvalue = 0.354'),
#  Text(0.25, 0.5, 'x[0] <= 0.092\nsquared_error = 0.038\nsamples = 44\nvalue = 0.689'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 0.018\nsamples = 20\nvalue = 0.854'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 0.013\nsamples = 24\nvalue = 0.552'),
#  Text(0.75, 0.5, 'x[0] <= 0.772\nsquared_error = 0.074\nsamples = 156\nvalue = 0.259'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 0.015\nsamples = 110\nvalue = 0.111'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 0.036\nsamples = 46\nvalue = 0.615')]

# %%
tree_reg = DecisionTreeRegressor(min_samples_leaf=10, random_state=42)
tree_reg.fit(X, y)
plot_tree(tree_reg,
        filled=True)
# Out:
# [Text(0.4551282051282051, 0.9375, 'x[0] <= 0.197\nsquared_error = 0.098\nsamples = 200\nvalue = 0.354'),
#  Text(0.20512820512820512, 0.8125, 'x[0] <= 0.092\nsquared_error = 0.038\nsamples = 44\nvalue = 0.689'),
#  Text(0.10256410256410256, 0.6875, 'x[0] <= 0.046\nsquared_error = 0.018\nsamples = 20\nvalue = 0.854'),
#  Text(0.05128205128205128, 0.5625, 'squared_error = 0.012\nsamples = 10\nvalue = 0.947'),
#  Text(0.15384615384615385, 0.5625, 'squared_error = 0.006\nsamples = 10\nvalue = 0.761'),
#  Text(0.3076923076923077, 0.6875, 'x[0] <= 0.139\nsquared_error = 0.013\nsamples = 24\nvalue = 0.552'),
#  Text(0.2564102564102564, 0.5625, 'squared_error = 0.01\nsamples = 10\nvalue = 0.614'),
#  Text(0.358974358974359, 0.5625, 'squared_error = 0.011\nsamples = 14\nvalue = 0.508'),
#  Text(0.7051282051282052, 0.8125, 'x[0] <= 0.772\nsquared_error = 0.074\nsamples = 156\nvalue = 0.259'),
#  Text(0.5128205128205128, 0.6875, 'x[0] <= 0.287\nsquared_error = 0.015\nsamples = 110\nvalue = 0.111'),
#  Text(0.46153846153846156, 0.5625, 'squared_error = 0.006\nsamples = 19\nvalue = 0.236'),
#  Text(0.5641025641025641, 0.5625, 'x[0] <= 0.628\nsquared_error = 0.013\nsamples = 91\nvalue = 0.084'),
#  Text(0.4358974358974359, 0.4375, 'x[0] <= 0.422\nsquared_error = 0.011\nsamples = 64\nvalue = 0.044'),
#  Text(0.3333333333333333, 0.3125, 'x[0] <= 0.319\nsquared_error = 0.011\nsamples = 29\nvalue = 0.088'),
#  Text(0.28205128205128205, 0.1875, 'squared_error = 0.01\nsamples = 10\nvalue = 0.054'),
#  Text(0.38461538461538464, 0.1875, 'squared_error = 0.011\nsamples = 19\nvalue = 0.106'),
#  Text(0.5384615384615384, 0.3125, 'x[0] <= 0.558\nsquared_error = 0.008\nsamples = 35\nvalue = 0.007'),
#  Text(0.48717948717948717, 0.1875, 'x[0] <= 0.517\nsquared_error = 0.009\nsamples = 25\nvalue = -0.001'),
#  Text(0.4358974358974359, 0.0625, 'squared_error = 0.009\nsamples = 15\nvalue = 0.011'),
#  Text(0.5384615384615384, 0.0625, 'squared_error = 0.008\nsamples = 10\nvalue = -0.02'),
#  Text(0.5897435897435898, 0.1875, 'squared_error = 0.005\nsamples = 10\nvalue = 0.028'),
#  Text(0.6923076923076923, 0.4375, 'x[0] <= 0.707\nsquared_error = 0.005\nsamples = 27\nvalue = 0.181'),
#  Text(0.6410256410256411, 0.3125, 'squared_error = 0.003\nsamples = 15\nvalue = 0.147'),
#  Text(0.7435897435897436, 0.3125, 'squared_error = 0.005\nsamples = 12\nvalue = 0.223'),
#  Text(0.8974358974358975, 0.6875, 'x[0] <= 0.904\nsquared_error = 0.036\nsamples = 46\nvalue = 0.615'),
#  Text(0.8461538461538461, 0.5625, 'x[0] <= 0.862\nsquared_error = 0.012\nsamples = 28\nvalue = 0.489'),
#  Text(0.7948717948717948, 0.4375, 'squared_error = 0.005\nsamples = 16\nvalue = 0.42'),
#  Text(0.8974358974358975, 0.4375, 'squared_error = 0.006\nsamples = 12\nvalue = 0.579'),
#  Text(0.9487179487179487, 0.5625, 'squared_error = 0.01\nsamples = 18\nvalue = 0.811')]
